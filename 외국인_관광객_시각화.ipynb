# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/iesilder/projectForeign/blob/master/%EC%99%B8%EA%B5%AD%EC%9D%B8_%EA%B4%80%EA%B4%91%EA%B0%9D_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = [2004+i for i in range(14)]
y_data = [5818138, 6022752, 6155046, 6448240, 6890841, 7817533, 
          8797658, 9794796, 11140028, 12175550, 14201516, 13231651, 17241823, 13335758]

# %%
plt.title('Foreign visitors by Year')
plt.xlabel("YEAR")
plt.xticks(x_data)
plt.ylabel("Foreing visitors")
plt.plot(x_data, y_data, 'ro--')

# %%
xx_data = np.array([i+1 for i in range(12)])
yy_data = np.array([1220695, 1252080, 1233640, 1075899, 977889, 991802, 1008671, 
           1103506, 1078653, 1165638, 1093217, 1134068])
xa_data = [str(i+1)+'월' for i in range(11)]

# %%
plt.title('Foreign visitors by Month in 2017')
plt.xlabel("MONTH")
plt.xticks(xx_data)
plt.ylabel("Foreing visitors")
plt.plot(xx_data, yy_data, 'bo--')
